# %%
import semantic_objects as tb
import semantic_objects.s223 as s223
from pprint import pprint
# Out:
# CRITICAL:root:Install the 'bacnet-ingress' module, e.g. 'pip install buildingmotif[bacnet-ingress]'

# %%
vars(s223.Area)
# Out:
# mappingproxy({'__module__': 'semantic_objects.s223.values',
#               'qk': semantic_objects.qudt.quantitykinds.Area,
#               '__doc__': 'Area(unit: semantic_objects.units.Unit, value: semantic_objects.core.Value)',
#               '__annotations__': {'qk': semantic_objects.qudt.quantitykinds.QuantityKind},
#               'abstract': False,
#               '__dataclass_params__': _DataclassParams(init=True,repr=True,eq=True,order=False,unsafe_hash=False,frozen=False),
#               '__dataclass_fields__': {'qk': Field(name='qk',type=<class 'semantic_objects.qudt.quantitykinds.QuantityKind'>,default=<class 'semantic_objects.qudt.quantitykinds.Area'>,default_factory=<dataclasses._MISSING_TYPE object at 0x10383b910>,init=False,repr=True,hash=None,compare=True,metadata=mappingproxy({}),kw_only=False,_field_type=_FIELD),
#                'unit': Field(name='unit',type=<class 'semantic_objects.units.Unit'>,default=<dataclasses._MISSING_TYPE object at 0x10383b910>,default_factory=<dataclasses._MISSING_TYPE object at 0x10383b910>,init=True,repr=True,hash=None,compare=True,metadata=mappingproxy({'relation': None, 'min': 1, 'max': None, 'qualified': True, 'label': None, 'comment': None}),kw_only=False,_field_type=_FIELD),
#                'value': Field(name='value',type=<class 'semantic_objects.core.Value'>,default=<dataclasses._MISSING_TYPE object at 0x10383b910>,default_factory=<dataclasses._MISSING_TYPE object at 0x10383b910>,init=True,repr=True,hash=None,compare=True,metadata=mappingproxy({'relation': None, 'min': 1, 'max': None, 'qualified': True, 'label': None, 'comment': None}),kw_only=False,_field_type=_FIELD)},
#               '__init__': <function semantic_objects.s223.values.Area.__init__(self, unit: semantic_objects.units.Unit, value: semantic_objects.core.Value) -> None>,
#               '__repr__': <function semantic_objects.s223.values.Area.__repr__(self)>,
#               '__eq__': <function semantic_objects.s223.values.Area.__eq__(self, other)>,
#               '__hash__': None,
#               '__match_args__': ('unit', 'value')})

# %%
print(s223.Space.generate_turtle_body())
# Out:
# @prefix P: <urn:___param___#> .
# @prefix s223: <http://data.ashrae.org/standard223#> .
#
# P:name a s223:PhysicalSpace ;
#     s223:hasProperty P:area .

# %%
s223.Space.__dataclass_fields__
# Out:
# {'area': Field(name='area',type=<class 'semantic_objects.s223.values.Area'>,default=<dataclasses._MISSING_TYPE object at 0x10383b910>,default_factory=<dataclasses._MISSING_TYPE object at 0x10383b910>,init=True,repr=True,hash=None,compare=True,metadata=mappingproxy({'relation': None, 'min': 1, 'max': None, 'qualified': True, 'label': None, 'comment': None}),kw_only=False,_field_type=_FIELD)}

# %%
from dataclasses import _MISSING_TYPE
isinstance(s223.Space.__dataclass_fields__['area'].default, _MISSING_TYPE)
# Out:
# True

# %%
s223.Area.__dataclass_fields__['qk'].default
# Out:
# semantic_objects.qudt.quantitykinds.Area

# %%
print(s223.Space_TwoArea.generate_turtle_body())
# Out:
# @prefix P: <urn:___param___#> .
# @prefix s223: <http://data.ashrae.org/standard223#> .
#
# P:name a s223:PhysicalSpace ;
#     s223:hasProperty P:area,
#         P:area2 .

# %%
print(s223.Space.to_yaml())
# Out:
# Space:
#   body: |+
#     @prefix P: <urn:___param___#> .
#     @prefix s223: <http://data.ashrae.org/standard223#> .
#
#     P:name a s223:PhysicalSpace ;
#         s223:hasProperty P:area .
#
#   dependencies:
#   - args:
#       name: area
#     template: Area

# %%
print(s223.Space.generate_rdf_class_definition())
# Out:
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix s223: <http://data.ashrae.org/standard223#> .
# @prefix sh: <http://www.w3.org/ns/shacl#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# s223:PhysicalSpace a s223:Class,
#         sh:NodeShape ;
#     rdfs:label "Physical Space" ;
#     rdfs:comment "A `PhysicalSpace` is an architectural concept representing a room, a part of a room, a collection of rooms, or any other physical region in a building. PhysicalSpaces may be grouped to define larger `PhysicalSpace`s using the relation `contains` (see {s223:contains})." ;
#     rdfs:subClassOf s223:Class ;
#     sh:property [ a sh:PropertyShape ;
#             rdfs:comment "If the relation `hasProperty` is present it must associate the `Space` with a `Area`." ;
#             sh:class s223:QuantifiableObservableProperty ;
#             sh:message "s223: If the relation `hasProperty` is present it must associate the `Space` with a `Area`." ;
#             sh:minCount 1 ;
#             sh:path s223:hasProperty ;
#             sh:qualifiedMinCount 1 ;
#             sh:qualifiedValueShape [ a sh:NodeShape ;
#                     rdfs:label "None" ;
#                     sh:class s223:QuantifiableObservableProperty ] ] .

# %%
print(s223.Space.generate_rdf_class_definition(include_hierarchy=True))
# Out:
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix s223: <http://data.ashrae.org/standard223#> .
# @prefix sh: <http://www.w3.org/ns/shacl#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# s223:PhysicalSpace a s223:Class,
#         sh:NodeShape ;
#     rdfs:label "Physical Space" ;
#     rdfs:comment "A `PhysicalSpace` is an architectural concept representing a room, a part of a room, a collection of rooms, or any other physical region in a building. PhysicalSpaces may be grouped to define larger `PhysicalSpace`s using the relation `contains` (see {s223:contains})." ;
#     rdfs:subClassOf s223:Class ;
#     sh:property [ a sh:PropertyShape ;
#             rdfs:comment "If the relation `encloses` is present it must associate the `Space` with a `DomainSpace`." ;
#             sh:class s223:DomainSpace ;
#             sh:message "s223: If the relation `encloses` is present it must associate the `Space` with a `DomainSpace`." ;
#             sh:path s223:encloses ],
#         [ a sh:PropertyShape ;
#             rdfs:comment "If the relation `contains` is present it must associate the `Space` with a `Space`." ;
#             sh:class s223:PhysicalSpace ;
#             sh:message "s223: If the relation `contains` is present it must associate the `Space` with a `Space`." ;
#             sh:path s223:contains ],
#         [ a sh:PropertyShape ;
#             rdfs:comment "If the relation `hasProperty` is present it must associate the `Space` with a `Area`." ;
#             sh:class s223:QuantifiableObservableProperty ;
#             sh:message "s223: If the relation `hasProperty` is present it must associate the `Space` with a `Area`." ;
#             sh:minCount 1 ;
#             sh:path s223:hasProperty ;
#             sh:qualifiedMinCount 1 ;
#             sh:qualifiedValueShape [ a sh:NodeShape ;
#                     rdfs:label "None" ;
#                     sh:class s223:QuantifiableObservableProperty ] ] .

# %%
s223.Space.get_relations()
# Out:
# [(semantic_objects.s223.relations.hasProperty, 'area')]

# %%
s223.Space.__dataclass_fields__
# Out:
# {'area': Field(name='area',type=<class 'semantic_objects.s223.values.Area'>,default=<dataclasses._MISSING_TYPE object at 0x10383b910>,default_factory=<dataclasses._MISSING_TYPE object at 0x10383b910>,init=True,repr=True,hash=None,compare=True,metadata=mappingproxy({'relation': None, 'min': 1, 'max': None, 'qualified': True, 'label': None, 'comment': None}),kw_only=False,_field_type=_FIELD)}

# %%
# necessary templates

# %%
tb.core.get_related_classes(s223.Space)
# Out:
# ([semantic_objects.s223.relations.hasProperty,
#   semantic_objects.s223.relations.hasValue,
#   semantic_objects.s223.relations.hasQuantityKind,
#   semantic_objects.s223.relations.hasUnit],
#  [semantic_objects.s223.entities.Space],
#  [semantic_objects.s223.values.Area])

# %%
tb.core.get_related_classes(s223.Space_TwoArea, get_recursive=True)
# Out:
# ([semantic_objects.s223.relations.hasProperty,
#   semantic_objects.s223.relations.hasValue,
#   semantic_objects.s223.relations.hasQuantityKind,
#   semantic_objects.s223.relations.hasUnit],
#  [semantic_objects.s223.entities.Space_TwoArea],
#  [semantic_objects.s223.values.Area])

# %%
predicate_lst, entity_lst, value_lst = s223.get_module_classes()
pprint(f'{predicate_lst=}')
print("-" * 60)
pprint(f'{entity_lst=}')
print("-" * 60)
pprint(f'{value_lst=}')
# Out:
# ("predicate_lst=[<class 'semantic_objects.s223.relations.hasValue'>, <class "
#  "'semantic_objects.s223.relations.hasQuantityKind'>, <class "
#  "'semantic_objects.s223.relations.hasUnit'>, <class "
#  "'semantic_objects.s223.relations.hasProperty'>, <class "
#  "'semantic_objects.s223.relations.contains'>, <class "
#  "'semantic_objects.s223.relations.encloses'>, <class "
#  "'semantic_objects.s223.relations.hasConnectionPoint'>, <class "
#  "'semantic_objects.s223.relations.hasMedium'>, <class "
#  "'semantic_objects.s223.relations.connectedTo'>, <class "
#  "'semantic_objects.s223.relations.hasWindow'>, <class "
#  "'semantic_objects.s223.relations.hasExternalReference'>]")
# ------------------------------------------------------------
# ("entity_lst=[<class 'semantic_objects.s223.entities.Entity'>, <class "
#  "'semantic_objects.s223.entities.DomainSpace'>, <class "
#  "'semantic_objects.s223.entities.PhysicalSpace'>, <class "
#  "'semantic_objects.s223.entities.Space'>, <class "
#  "'semantic_objects.s223.entities.Space_TwoArea'>, <class "
#  "'semantic_objects.s223.entities.Window'>]")
# ------------------------------------------------------------
# ("value_lst=[<class 'semantic_objects.s223.values.Area'>, <class "
#  "'semantic_objects.s223.values.Azimuth'>, <class "
#  "'semantic_objects.s223.values.Tilt'>, <class "
#  "'semantic_objects.s223.values.QuantifiableObervableProperty'>, <class "
#  "'semantic_objects.s223.values.Property'>, <class "
#  "'semantic_objects.s223.values.QOP_Value'>, <class "
#  "'semantic_objects.s223.values.QOP_Ref_or_Val'>, <class "
#  "'semantic_objects.s223.values.Area_ext'>]")

# %%
predicate_lst, entity_lst, value_lst = tb.core.get_related_classes([s223.Space, s223.Window], get_recursive=True)
pprint(f'{predicate_lst=}')
print("-" * 60)
pprint(f'{entity_lst=}')
print("-" * 60)
pprint(f'{value_lst=}')
# Out:
# ("predicate_lst=[<class 'semantic_objects.s223.relations.hasProperty'>, <class "
#  "'semantic_objects.s223.relations.hasValue'>, <class "
#  "'semantic_objects.s223.relations.hasQuantityKind'>, <class "
#  "'semantic_objects.s223.relations.hasUnit'>]")
# ------------------------------------------------------------
# ("entity_lst=[<class 'semantic_objects.s223.entities.Space'>, <class "
#  "'semantic_objects.s223.entities.Window'>]")
# ------------------------------------------------------------
# ("value_lst=[<class 'semantic_objects.s223.values.Area'>, <class "
#  "'semantic_objects.s223.values.Azimuth'>, <class "
#  "'semantic_objects.s223.values.Tilt'>]")

# %%
class_set = tb.core.get_related_classes(s223.Space_TwoArea, get_recursive=True)

# %%
flat_class_set = [item for sublist in class_set for item in sublist] # flatten class_set

# %%
for klass in flat_class_set:
    print(klass.generate_turtle_body())
# Out:
# @prefix P: <urn:___param___#> .
# @prefix s223: <http://data.ashrae.org/standard223#> .
#
# P:name s223:hasProperty P:target .
#
#
# @prefix P: <urn:___param___#> .
# @prefix s223: <http://data.ashrae.org/standard223#> .
#
# P:name s223:hasValue P:target .
#
#
# @prefix P: <urn:___param___#> .
# @prefix qudt: <http://qudt.org/schema/qudt/> .
#
# P:name qudt:hasQuantityKind P:target .
#
#
# @prefix P: <urn:___param___#> .
# @prefix s223: <http://data.ashrae.org/standard223#> .
#
# P:name s223:hasUnit P:target .
#
#
# @prefix P: <urn:___param___#> .
# @prefix s223: <http://data.ashrae.org/standard223#> .
#
# P:name a s223:PhysicalSpace ;
#     s223:hasProperty P:area,
#         P:area2 .
#
#
# @prefix P: <urn:___param___#> .
# @prefix quantitykind: <http://qudt.org/vocab/quantitykind/> .
# @prefix qudt: <http://qudt.org/schema/qudt/> .
# @prefix s223: <http://data.ashrae.org/standard223#> .
#
# P:name a s223:QuantifiableObservableProperty ;
#     s223:hasUnit P:unit ;
#     s223:hasValue P:value ;
#     qudt:hasQuantityKind quantitykind:Area .

# %%
tb.core.export_templates([s223.Space, s223.Window], 's223-test-templates')

# %%
s223.Value.abstract
# Out:
# True

# %%
print(s223.hasProperty.to_yaml())
# Out:
# hasProperty:
#   body: |+
#     @prefix P: <urn:___param___#> .
#     @prefix s223: <http://data.ashrae.org/standard223#> .
#
#     P:name s223:hasProperty P:target .
#
#   dependencies: []

# %%
# test to see if we can load these in buildingmotif 
from buildingmotif import BuildingMOTIF
from buildingmotif.dataclasses import Library, Model

bm = BuildingMOTIF("sqlite://")
templates = Library.load(directory='s223-test-templates')
templates.get_templates()
# Out:
# DEBUG:buildingmotif.database.graph_connection:Creating tables for graph storage
# DEBUG:buildingmotif.database.table_connection:Creating shape collection in library: 's223-test-templates'
# DEBUG:buildingmotif.database.table_connection:Creating database library: 's223-test-templates'
# DEBUG:buildingmotif.database.table_connection:Creating database template: 'Space'
# DEBUG:buildingmotif.database.graph_connection:Creating graph: '39aa8e2a-991b-479f-a2f5-d1f3bd063221' in database with: 2 triples
# DEBUG:buildingmotif.database.table_connection:Creating database template: 'Window'
# DEBUG:buildingmotif.database.graph_connection:Creating graph: 'daeba23f-3832-428b-97eb-577636eae37f' in database with: 4 triples
# DEBUG:buildingmotif.database.table_connection:Creating database template: 'hasProperty'
# DEBUG:buildingmotif.database.graph_connection:Creating graph: 'a7b27eab-0632-4b10-af5a-7920cb832316' in database with: 1 triples
# DEBUG:buildingmotif.database.table_connection:Creating database template: 'hasValue'
# DEBUG:buildingmotif.database.graph_connection:Creating graph: '2f69b47f-c010-44e9-9dc7-41c976ab4820' in database with: 1 triples
# DEBUG:buildingmotif.database.table_connection:Creating database template: 'hasQuantityKind'
# DEBUG:buildingmotif.database.graph_connection:Creating graph: '52d7d638-36c1-4d19-8d9e-db75d2bb67cb' in database with: 1 triples
# DEBUG:buildingmotif.database.table_connection:Creating database template: 'hasUnit'
# DEBUG:buildingmotif.database.graph_connection:Creating graph: '477c9861-993b-4e12-8bee-9d70422db473' in database with: 1 triples
# DEBUG:buildingmotif.database.table_connection:Creating database template: 'Area'
# DEBUG:buildingmotif.database.graph_connection:Creating graph: '8f75ebfa-9ea8-4cac-ab2b-42043b8503e7' in database with: 4 triples
# DEBUG:buildingmotif.database.table_connection:Creating database template: 'Azimuth'
# DEBUG:buildingmotif.database.graph_connection:Creating graph: 'b20be04d-3236-4d34-ae8c-24275092ef0c' in database with: 4 triples
# DEBUG:buildingmotif.database.table_connection:Creating database template: 'Tilt'
# DEBUG:buildingmotif.database.graph_connection:Creating graph: '29cb4b6b-229d-47e4-94f7-9da9a1530487' in database with: 4 triples
# DEBUG:buildingmotif.database.table_connection:Creating depencency from templates with ids: '1' and: '7'
# DEBUG:buildingmotif.database.table_connection:Creating depencency from templates with ids: '2' and: '7'
# DEBUG:buildingmotif.database.table_connection:Creating depencency from templates with ids: '2' and: '8'
# DEBUG:buildingmotif.database.table_connection:Creating depencency from templates with ids: '2' and: '9'
# DEBUG:buildingmotif.database.table_connection:Creating depencency from templates with ids: '1' and: '7'
# DEBUG:buildingmotif.database.table_connection:Creating depencency from templates with ids: '2' and: '7'
# DEBUG:buildingmotif.database.table_connection:Creating depencency from templates with ids: '2' and: '8'
# DEBUG:buildingmotif.database.table_connection:Creating depencency from templates with ids: '2' and: '9'
# /Users/lazlopaul/Desktop/HPflex/semantic_objects/.venv/lib/python3.11/site-packages/pyshacl/extras/__init__.py:46: Warning: Extra "js" is not satisfied because requirement pyduktape2 is not installed.
#   warn(Warning(f"Extra \"{extra_name}\" is not satisfied because requirement {req} is not installed."))
# [Template(_id=1, _name='Space', body=<Graph identifier=39aa8e2a-991b-479f-a2f5-d1f3bd063221 (<class 'rdflib.graph.Graph'>)>, optional_args=[], _bm=<buildingmotif.building_motif.building_motif.BuildingMOTIF object at 0x10c00f050>),
#  Template(_id=2, _name='Window', body=<Graph identifier=daeba23f-3832-428b-97eb-577636eae37f (<class 'rdflib.graph.Graph'>)>, optional_args=[], _bm=<buildingmotif.building_motif.building_motif.BuildingMOTIF object at 0x10c00f050>),
#  Template(_id=3, _name='hasProperty', body=<Graph identifier=a7b27eab-0632-4b10-af5a-7920cb832316 (<class 'rdflib.graph.Graph'>)>, optional_args=[], _bm=<buildingmotif.building_motif.building_motif.BuildingMOTIF object at 0x10c00f050>),
#  Template(_id=4, _name='hasValue', body=<Graph identifier=2f69b47f-c010-44e9-9dc7-41c976ab4820 (<class 'rdflib.graph.Graph'>)>, optional_args=[], _bm=<buildingmotif.building_motif.building_motif.BuildingMOTIF object at 0x10c00f050>),
#  Template(_id=5, _name='hasQuantityKind', body=<Graph identifier=52d7d638-36c1-4d19-8d9e-db75d2bb67cb (<class 'rdflib.graph.Graph'>)>, optional_args=[], _bm=<buildingmotif.building_motif.building_motif.BuildingMOTIF object at 0x10c00f050>),
#  Template(_id=6, _name='hasUnit', body=<Graph identifier=477c9861-993b-4e12-8bee-9d70422db473 (<class 'rdflib.graph.Graph'>)>, optional_args=[], _bm=<buildingmotif.building_motif.building_motif.BuildingMOTIF object at 0x10c00f050>),
#  Template(_id=7, _name='Area', body=<Graph identifier=8f75ebfa-9ea8-4cac-ab2b-42043b8503e7 (<class 'rdflib.graph.Graph'>)>, optional_args=[], _bm=<buildingmotif.building_motif.building_motif.BuildingMOTIF object at 0x10c00f050>),
#  Template(_id=8, _name='Azimuth', body=<Graph identifier=b20be04d-3236-4d34-ae8c-24275092ef0c (<class 'rdflib.graph.Graph'>)>, optional_args=[], _bm=<buildingmotif.building_motif.building_motif.BuildingMOTIF object at 0x10c00f050>),
#  Template(_id=9, _name='Tilt', body=<Graph identifier=29cb4b6b-229d-47e4-94f7-9da9a1530487 (<class 'rdflib.graph.Graph'>)>, optional_args=[], _bm=<buildingmotif.building_motif.building_motif.BuildingMOTIF object at 0x10c00f050>)]
