# %%
import semantic_objects as tb
import semantic_objects.s223 as s223
from pprint import pprint
# Out:
# CRITICAL:root:Install the 'bacnet-ingress' module, e.g. 'pip install buildingmotif[bacnet-ingress]'

# %%
vars(s223.Area)
# Out:
# mappingproxy({'__module__': 'semantic_objects.s223.values',
#               '_local_name': 'Area',
#               'qk': semantic_objects.qudt.quantitykinds.Area,
#               '__doc__': 'Area(value: semantic_objects.core.Value, unit: semantic_objects.units.Unit)',
#               '__annotations__': {'qk': semantic_objects.qudt.quantitykinds.QuantityKind},
#               '__dataclass_params__': _DataclassParams(init=True,repr=True,eq=True,order=False,unsafe_hash=False,frozen=False),
#               '__dataclass_fields__': {'qk': Field(name='qk',type=<class 'semantic_objects.qudt.quantitykinds.QuantityKind'>,default=<class 'semantic_objects.qudt.quantitykinds.Area'>,default_factory=<dataclasses._MISSING_TYPE object at 0x102eb02d0>,init=False,repr=True,hash=None,compare=True,metadata=mappingproxy({}),kw_only=False,_field_type=_FIELD),
#                'value': Field(name='value',type=<class 'semantic_objects.core.Value'>,default=<dataclasses._MISSING_TYPE object at 0x102eb02d0>,default_factory=<dataclasses._MISSING_TYPE object at 0x102eb02d0>,init=True,repr=True,hash=None,compare=True,metadata=mappingproxy({'relation': None, 'min': 1, 'max': None, 'qualified': True, 'label': None, 'comment': None}),kw_only=False,_field_type=_FIELD),
#                'unit': Field(name='unit',type=<class 'semantic_objects.units.Unit'>,default=<dataclasses._MISSING_TYPE object at 0x102eb02d0>,default_factory=<dataclasses._MISSING_TYPE object at 0x102eb02d0>,init=True,repr=True,hash=None,compare=True,metadata=mappingproxy({'relation': None, 'min': 1, 'max': None, 'qualified': True, 'label': None, 'comment': None}),kw_only=False,_field_type=_FIELD)},
#               '__init__': <function semantic_objects.s223.values.Area.__init__(self, value: semantic_objects.core.Value, unit: semantic_objects.units.Unit) -> None>,
#               '__repr__': <function semantic_objects.s223.values.Area.__repr__(self)>,
#               '__eq__': <function semantic_objects.s223.values.Area.__eq__(self, other)>,
#               '__hash__': None,
#               '__match_args__': ('value', 'unit')})

# %%
print(s223.Space.generate_turtle_body())
# Out:
# @prefix P: <urn:___param___#> .
# @prefix s223: <http://data.ashrae.org/standard223#> .
#
# P:name a s223:PhysicalSpace ;
#     s223:hasProperty P:area .

# %%
from dataclasses import _MISSING_TYPE
isinstance(s223.Space.__dataclass_fields__['area'].default, _MISSING_TYPE)
# Out:
# True

# %%
s223.Area.__dataclass_fields__['qk'].default
# Out:
# semantic_objects.qudt.quantitykinds.Area

# %%
print(s223.Space_TwoArea.generate_turtle_body())
# Out:
# @prefix P: <urn:___param___#> .
# @prefix s223: <http://data.ashrae.org/standard223#> .
#
# P:name a s223:Space ;
#     s223:hasProperty P:area,
#         P:area2 .

# %%
print(s223.Space.to_yaml_str())
# Out:
# Space:
#   body: |+
#     @prefix P: <urn:___param___#> .
#     @prefix s223: <http://data.ashrae.org/standard223#> .
#
#     P:name a s223:PhysicalSpace ;
#         s223:hasProperty P:area .
#
#   dependencies:
#   - args:
#       name: area
#     template: Area

# %%
print(s223.Space.generate_rdf_class_definition())
# Out:
# FIELDS TO PROCESS: ['area']
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix s223: <http://data.ashrae.org/standard223#> .
# @prefix sh: <http://www.w3.org/ns/shacl#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# s223:PhysicalSpace a s223:Class,
#         sh:NodeShape ;
#     rdfs:label "Physical Space" ;
#     rdfs:comment "A `PhysicalSpace` is an architectural concept representing a room, a part of a room, a collection of rooms, or any other physical region in a building. PhysicalSpaces may be grouped to define larger `PhysicalSpace`s using the relation `contains` (see {s223:contains})." ;
#     sh:property [ a sh:PropertyShape ;
#             rdfs:comment "If the relation `hasProperty` is present it must associate the `Space` with a `Area`." ;
#             sh:class s223:Area ;
#             sh:message "s223: If the relation `hasProperty` is present it must associate the `Space` with a `Area`." ;
#             sh:minCount 1 ;
#             sh:path s223:hasProperty ;
#             sh:qualifiedMinCount 1 ;
#             sh:qualifiedValueShape [ a sh:NodeShape ;
#                     rdfs:label "None" ;
#                     sh:class s223:Area ] ] .

# %%
print(s223.Space.generate_rdf_class_definition(include_hierarchy=True))
# Out:
# FIELDS TO PROCESS: ['area']
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix s223: <http://data.ashrae.org/standard223#> .
# @prefix sh: <http://www.w3.org/ns/shacl#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# s223:PhysicalSpace a s223:Class,
#         sh:NodeShape ;
#     rdfs:label "Physical Space" ;
#     rdfs:comment "A `PhysicalSpace` is an architectural concept representing a room, a part of a room, a collection of rooms, or any other physical region in a building. PhysicalSpaces may be grouped to define larger `PhysicalSpace`s using the relation `contains` (see {s223:contains})." ;
#     sh:property [ a sh:PropertyShape ;
#             rdfs:comment "If the relation `hasProperty` is present it must associate the `Space` with a `Area`." ;
#             sh:class s223:Area ;
#             sh:message "s223: If the relation `hasProperty` is present it must associate the `Space` with a `Area`." ;
#             sh:minCount 1 ;
#             sh:path s223:hasProperty ;
#             sh:qualifiedMinCount 1 ;
#             sh:qualifiedValueShape [ a sh:NodeShape ;
#                     rdfs:label "None" ;
#                     sh:class s223:Area ] ],
#         [ a sh:PropertyShape ;
#             rdfs:comment "If the relation `encloses` is present it must associate the `Space` with a `DomainSpace`." ;
#             sh:class s223:DomainSpace ;
#             sh:message "s223: If the relation `encloses` is present it must associate the `Space` with a `DomainSpace`." ;
#             sh:path s223:encloses ],
#         [ a sh:PropertyShape ;
#             rdfs:comment "If the relation `contains` is present it must associate the `Space` with a `Space`." ;
#             sh:class s223:PhysicalSpace ;
#             sh:message "s223: If the relation `contains` is present it must associate the `Space` with a `Space`." ;
#             sh:path s223:contains ] .

# %%
s223.Space.get_relations()
# Out:
# [(semantic_objects.s223.relations.hasProperty, 'area')]

# %%
s223.Space.__dataclass_fields__
# Out:
# {'area': Field(name='area',type=<class 'semantic_objects.s223.values.Area'>,default=<dataclasses._MISSING_TYPE object at 0x102eb02d0>,default_factory=<dataclasses._MISSING_TYPE object at 0x102eb02d0>,init=True,repr=True,hash=None,compare=True,metadata=mappingproxy({'relation': None, 'min': 1, 'max': None, 'qualified': True, 'label': None, 'comment': None}),kw_only=False,_field_type=_FIELD)}

# %%
# necessary templates

# %%
tb.core.get_related_classes(s223.Space)
# Out:
# [semantic_objects.s223.values.Area,
#  semantic_objects.s223.relations.hasProperty,
#  semantic_objects.s223.entities.Space]

# %%
tb.core.get_related_classes(s223.Space_TwoArea, get_recursive=True)
# Out:
# [semantic_objects.s223.entities.Space_TwoArea,
#  semantic_objects.s223.relations.hasProperty,
#  semantic_objects.s223.values.Area]

# %%
predicate_lst, entity_lst, value_lst = s223.get_all_classes()
pprint(f'{predicate_lst=}')
print("-" * 60)
pprint(f'{entity_lst=}')
print("-" * 60)
pprint(f'{value_lst=}')
# Out:
# ("predicate_lst=[<class 'semantic_objects.s223.relations.Predicate'>, <class "
#  "'semantic_objects.s223.relations.hasValue'>, <class "
#  "'semantic_objects.s223.relations.hasUnit'>, <class "
#  "'semantic_objects.s223.relations.hasProperty'>, <class "
#  "'semantic_objects.s223.relations.contains'>, <class "
#  "'semantic_objects.s223.relations.encloses'>, <class "
#  "'semantic_objects.s223.relations.hasQuantityKind'>, <class "
#  "'semantic_objects.s223.relations.hasConnectionPoint'>, <class "
#  "'semantic_objects.s223.relations.hasMedium'>, <class "
#  "'semantic_objects.s223.relations.connectedTo'>, <class "
#  "'semantic_objects.s223.relations.hasWindow'>]")
# ------------------------------------------------------------
# ("entity_lst=[<class 'semantic_objects.s223.entities.Entity'>, <class "
#  "'semantic_objects.s223.entities.DomainSpace'>, <class "
#  "'semantic_objects.s223.entities.PhysicalSpace'>, <class "
#  "'semantic_objects.s223.values.Area'>, <class "
#  "'semantic_objects.s223.relations.hasProperty'>, <class "
#  "'semantic_objects.s223.entities.Space'>, <class "
#  "'semantic_objects.s223.entities.Space_TwoArea'>, <class "
#  "'semantic_objects.s223.values.Azimuth'>, <class "
#  "'semantic_objects.s223.values.Tilt'>, <class "
#  "'semantic_objects.s223.entities.Window'>, <class "
#  "'semantic_objects.core.Entity'>]")
# ------------------------------------------------------------
# ("value_lst=[<class 'semantic_objects.core.Value'>, <class "
#  "'semantic_objects.s223.relations.hasQuantityKind'>, <class "
#  "'semantic_objects.s223.relations.hasValue'>, <class "
#  "'semantic_objects.qudt.quantitykinds.QuantityKind'>, <class "
#  "'semantic_objects.s223.values.Area'>, <class 'semantic_objects.units.Unit'>, "
#  "<class 'semantic_objects.s223.relations.hasUnit'>, <class "
#  "'semantic_objects.s223.values.Azimuth'>, <class "
#  "'semantic_objects.s223.values.Tilt'>, <class "
#  "'semantic_objects.s223.values.QuantifiableObervableProperty'>, <class "
#  "'semantic_objects.s223.values.Property'>]")
