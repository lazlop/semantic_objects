# %%
import semantic_objects as tb
import semantic_objects.s223 as s223
# Out:
# CRITICAL:root:Install the 'bacnet-ingress' module, e.g. 'pip install buildingmotif[bacnet-ingress]'

# %%
vars(s223.Space_TwoArea)
# Out:
# mappingproxy({'__module__': 'semantic_objects.s223.entities',
#               '__annotations__': {'area': semantic_objects.s223.values.Area,
#                'area2': semantic_objects.s223.values.Area},
#               '__doc__': 'Space_TwoArea(area: semantic_objects.s223.values.Area, area2: semantic_objects.s223.values.Area)',
#               '__dataclass_params__': _DataclassParams(init=True,repr=True,eq=True,order=False,unsafe_hash=False,frozen=False),
#               '__dataclass_fields__': {'area': Field(name='area',type=<class 'semantic_objects.s223.values.Area'>,default=<dataclasses._MISSING_TYPE object at 0x103088190>,default_factory=<dataclasses._MISSING_TYPE object at 0x103088190>,init=True,repr=True,hash=None,compare=True,metadata=mappingproxy({'relation': None, 'min': 1, 'max': None, 'qualified': True, 'label': None, 'comment': None}),kw_only=False,_field_type=_FIELD),
#                'area2': Field(name='area2',type=<class 'semantic_objects.s223.values.Area'>,default=<dataclasses._MISSING_TYPE object at 0x103088190>,default_factory=<dataclasses._MISSING_TYPE object at 0x103088190>,init=True,repr=True,hash=None,compare=True,metadata=mappingproxy({'relation': None, 'min': 1, 'max': None, 'qualified': True, 'label': None, 'comment': None}),kw_only=False,_field_type=_FIELD)},
#               '__init__': <function semantic_objects.s223.entities.Space_TwoArea.__init__(self, area: semantic_objects.s223.values.Area, area2: semantic_objects.s223.values.Area) -> None>,
#               '__repr__': <function semantic_objects.s223.entities.Space_TwoArea.__repr__(self)>,
#               '__eq__': <function semantic_objects.s223.entities.Space_TwoArea.__eq__(self, other)>,
#               '__hash__': None,
#               '__match_args__': ('area', 'area2')})

# %%
print(s223.Space_TwoArea.generate_turtle_body())
# Out:
# @prefix P: <urn:___param___#> .
# @prefix s223: <http://data.ashrae.org/standard223#> .
#
# P:name a s223:PhysicalSpace ;
#     s223:hasProperty P:area,
#         P:area2 .

# %%
print(s223.Space.to_yaml_str())
# Out:
# space:
#   body: |+
#     @prefix P: <urn:___param___#> .
#     @prefix s223: <http://data.ashrae.org/standard223#> .
#
#     P:name a s223:PhysicalSpace ;
#         s223:hasProperty P:area .
#
#   dependencies:
#   - args:
#       name: area
#     template: area

# %%
print(s223.Space.generate_rdf_class_definition())
# Out:
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix s223: <http://data.ashrae.org/standard223#> .
# @prefix sh: <http://www.w3.org/ns/shacl#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# s223:PhysicalSpace a s223:Class,
#         sh:NodeShape ;
#     rdfs:label "Physical Space" ;
#     rdfs:comment "A `PhysicalSpace` is an architectural concept representing a room, a part of a room, a collection of rooms, or any other physical region in a building. PhysicalSpaces may be grouped to define larger `PhysicalSpace`s using the relation `contains` (see {s223:contains})." ;
#     sh:property [ rdfs:comment "If the relation `hasProperty` is present it must associate the `Space` with a `Area`." ;
#             sh:class s223:QuantifiableObservableProperty ;
#             sh:message "s223: If the relation `hasProperty` is present it must associate the `Space` with a `Area`." ;
#             sh:minCount 1 ;
#             sh:path s223:hasProperty ] .

# %%
print(s223.Space.generate_rdf_class_definition(include_hierarchy=True))
# Out:
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix s223: <http://data.ashrae.org/standard223#> .
# @prefix sh: <http://www.w3.org/ns/shacl#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# s223:PhysicalSpace a s223:Class,
#         sh:NodeShape ;
#     rdfs:label "Physical Space" ;
#     rdfs:comment "A `PhysicalSpace` is an architectural concept representing a room, a part of a room, a collection of rooms, or any other physical region in a building. PhysicalSpaces may be grouped to define larger `PhysicalSpace`s using the relation `contains` (see {s223:contains})." ;
#     sh:property [ rdfs:comment "If the relation `hasProperty` is present it must associate the `Space` with a `Area`." ;
#             sh:class s223:QuantifiableObservableProperty ;
#             sh:message "s223: If the relation `hasProperty` is present it must associate the `Space` with a `Area`." ;
#             sh:minCount 1 ;
#             sh:path s223:hasProperty ],
#         [ rdfs:comment "If the relation `contains` is present it must associate the `Space` with a `PhysicalSpace`." ;
#             sh:class s223:PhysicalSpace ;
#             sh:message "s223: If the relation `contains` is present it must associate the `Space` with a `PhysicalSpace`." ;
#             sh:path s223:contains ],
#         [ rdfs:comment "If the relation `hasConnectionPoint` is present it must associate the `Space` with a `ConnectionPoint`." ;
#             sh:class s223:ConnectionPoint ;
#             sh:message "s223: If the relation `hasConnectionPoint` is present it must associate the `Space` with a `ConnectionPoint`." ;
#             sh:path s223:hasConnectionPoint ],
#         [ rdfs:comment "If the relation `encloses` is present it must associate the `Space` with a `DomainSpace`." ;
#             sh:class s223:DomainSpace ;
#             sh:message "s223: If the relation `encloses` is present it must associate the `Space` with a `DomainSpace`." ;
#             sh:path s223:encloses ] .
